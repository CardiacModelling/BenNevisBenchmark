# %%
import nevis
nevis.download_os_terrain_50()
nevis.howdy() # Print the current version number
# Out:
# Downloaded, unpacked, and processed file already found: Skipping.
#
#                 |>
#  Starting Ben   |   Nevis
#                / \    version
#             /\/---\     0.0.5
#            /---    \/\
#         /\/   /\   /  \
#      /\/  \  /  \_/    \
#     /      \/           \

# %%
f = nevis.linear_interpolant()
x_max, y_max = nevis.dimensions()

import pints

# Visited points, and means per iteration
points = []
trajectory = []

# Use best found, instead of best guessed
x_best = False


# Create pints error measure
class Error(pints.ErrorMeasure):
    """
    Turn a height into an error to be minimised.

    Writes to global var: not suitable for parallelistion!
    """
    def __init__(self, spline):
        self.f = spline

    def n_parameters(self):
        return 2

    def __call__(self, p):
        points.append(p)
        return -self.f(*p)


# Create callback to store means
def cb(i, opt):
    trajectory.append(opt.x_best() if x_best else opt.x_guessed())

b = pints.RectangularBoundaries([0, 0], [x_max, y_max])

fs = []
for _ in range(100):
    e = Error(f)
    x0 = b.sample()
    s0 = min(b.range()) / 5
    opt = pints.OptimisationController(
        e,
        x0=x0,
        sigma0=s0,
        boundaries=b,
        method=pints.CMAES
    )
    opt.optimiser().set_population_size(400)
    opt.set_callback(cb)
    opt.set_max_unchanged_iterations(100, threshold=0.01)

    opt.set_f_guessed_tracking(not x_best)
    x1, f1 = opt.run()

    # Get final result
    x, y = x1
    nevis.print_result(x, y, -f1)
    fs.append(-f1)
    print(f'Number of function evaluations: {len(points)}.')
# Out:
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400     -681.9627 -681.9627   0:00.0
# 1     800     -681.9627 -630.7061   0:00.0
# 2     1200    -790.5262 -790.5262   0:00.1
# 3     1600    -860.8732 -860.8732   0:00.1
# 20    8400    -1243.683 -1243.683   0:00.7
# 40    16400   -1308.988 -1308.988   0:01.4
# 60    24400   -1309.1   -1309.1     0:02.1
# 80    32400   -1309.1   -1309.1     0:02.7
# 100   40400   -1309.1   -1309.1     0:03.4
# 120   48400   -1309.1   -1309.1     0:04.0
# 140   56400   -1309.1   -1309.1     0:04.4
# 154   61600   -1309.1   -1309.1     0:04.6
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 1309m.
#   https://opentopomap.org/#marker=15/57.070204/-3.669488
# You are 31m from the nearest named hill top, "Ben Macdui",
#   ranked the 2d heighest in GB.
#   http://hillsummits.org.uk/htm_summit/518.htm
# Number of function evaluations: 61600.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400     -453.8073 -453.8073   0:00.0
# 1     800     -702.5892 -702.5892   0:00.0
# 2     1200    -853.1832 -853.1832   0:00.1
# 3     1600    -1076.539 -1076.539   0:00.1
# 20    8400    -1238.326 -1177.328   0:00.7
# 40    16400   -1308.593 -1308.593   0:01.4
# 60    24400   -1309.1   -1309.1     0:02.1
# 80    32400   -1309.1   -1309.1     0:02.8
# 100   40400   -1309.1   -1309.1     0:03.6
# 120   48400   -1309.1   -1309.1     0:04.1
# 140   56400   -1309.1   -1309.1     0:04.5
# 152   60800   -1309.1   -1309.1     0:04.7
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 1309m.
#   https://opentopomap.org/#marker=15/57.070204/-3.669488
# You are 31m from the nearest named hill top, "Ben Macdui",
#   ranked the 2d heighest in GB.
#   http://hillsummits.org.uk/htm_summit/518.htm
# Number of function evaluations: 122400.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400      0.0164    0.0164     0:00.0
# 1     800     -662.6061 -662.6061   0:00.0
# 2     1200    -662.6061 -655.0724   0:00.1
# 3     1600    -708.3239 -708.3239   0:00.1
# 20    8400    -942.6302 -489.1465   0:00.8
# 40    16400   -1110.61  -760.9082   0:01.7
# 60    24400   -1209.925 -1165.728   0:02.4
# 80    32400   -1308.774 -1308.665   0:03.2
# 100   40400   -1309.1   -1309.1     0:04.0
# 120   48400   -1309.1   -1309.1     0:04.8
# 140   56400   -1309.1   -1309.1     0:05.5
# 160   64400   -1309.1   -1309.1     0:06.0
# 180   72400   -1309.1   -1309.1     0:06.5
# 187   74800   -1309.1   -1309.1     0:06.7
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 1309m.
#   https://opentopomap.org/#marker=15/57.070204/-3.669488
# You are 31m from the nearest named hill top, "Ben Macdui",
#   ranked the 2d heighest in GB.
#   http://hillsummits.org.uk/htm_summit/518.htm
# Number of function evaluations: 197200.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400      0.131     0.131      0:00.0
# 1     800     -466.8113 -466.8113   0:00.0
# 2     1200    -834.0625 -834.0625   0:00.1
# 3     1600    -834.0625 -675.2168   0:00.1
# 20    8400    -970.3766 -828.854    0:00.8
# 40    16400   -970.3766 -855.1089   0:01.5
# 60    24400   -1269.624 -909.2402   0:02.4
# 80    32400   -1269.624 -1126.664   0:03.2
# 100   40400   -1269.624 -1094.084   0:04.1
# 120   48400   -1298.93  -1282.986   0:04.9
# 140   56400   -1308.62  -1303.07    0:05.6
# 160   64400   -1309.1   -1309.1     0:06.3
# 180   72400   -1309.1   -1309.1     0:07.0
# 200   80400   -1309.1   -1309.1     0:07.7
# 220   88400   -1309.1   -1309.1     0:08.3
# 240   96400   -1309.1   -1309.1     0:08.8
# 257   102800  -1309.1   -1309.1     0:09.1
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 1309m.
#   https://opentopomap.org/#marker=15/57.070204/-3.669488
# You are 31m from the nearest named hill top, "Ben Macdui",
#   ranked the 2d heighest in GB.
#   http://hillsummits.org.uk/htm_summit/518.htm
# Number of function evaluations: 300000.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400     -770.2043 -770.2043   0:00.0
# 1     800     -846.4765 -846.4765   0:00.0
# 2     1200    -1070.893 -1070.893   0:00.1
# 3     1600    -1070.893 -799.7561   0:00.1
# 20    8400    -1306.82  -1292.339   0:00.8
# 40    16400   -1309.098 -1309.098   0:01.5
# 60    24400   -1309.1   -1309.1     0:02.4
# 80    32400   -1309.1   -1309.1     0:03.1
# 100   40400   -1309.1   -1309.1     0:03.7
# 120   48400   -1309.1   -1309.1     0:04.2
# 139   55600   -1309.1   -1309.1     0:04.6
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 1309m.
#   https://opentopomap.org/#marker=15/57.070204/-3.669488
# You are 31m from the nearest named hill top, "Ben Macdui",
#   ranked the 2d heighest in GB.
#   http://hillsummits.org.uk/htm_summit/518.htm
# Number of function evaluations: 355600.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400     -877.0796 -877.0796   0:00.0
# 1     800     -970.603  -970.603    0:00.0
# 2     1200    -1156.02  -1156.02    0:00.1
# 3     1600    -1245.528 -1245.528   0:00.1
# 20    8400    -1306.857 -1306.857   0:00.8
# 40    16400   -1309.093 -1309.093   0:01.5
# 60    24400   -1309.1   -1309.1     0:02.3
# 80    32400   -1309.1   -1309.1     0:03.1
# 100   40400   -1309.1   -1309.1     0:03.8
# 120   48400   -1309.1   -1309.1     0:04.3
# 140   56000   -1309.1   -1309.1     0:04.7
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 1309m.
#   https://opentopomap.org/#marker=15/57.070204/-3.669488
# You are 31m from the nearest named hill top, "Ben Macdui",
#   ranked the 2d heighest in GB.
#   http://hillsummits.org.uk/htm_summit/518.htm
# Number of function evaluations: 411600.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400     -554.1249 -554.1249   0:00.0
# 1     800     -650.7304 -650.7304   0:00.0
# 2     1200    -650.7304 -534.0866   0:00.1
# 3     1600    -650.7304 -639.3531   0:00.1
# 20    8400    -673.5291 -460.6533   0:00.8
# 40    16400   -736.2562 -661.5486   0:01.6
# 60    24400   -772.9019 -772.9019   0:02.4
# 80    32400   -883.0514 -883.0514   0:03.1
# 100   40400   -883.5989 -883.5989   0:03.9
# 120   48400   -883.6    -883.6      0:04.7
# 140   56400   -883.6    -883.6      0:05.5
# 160   64400   -883.6    -883.6      0:06.2
# 180   72400   -883.6    -883.6      0:06.8
# 194   77600   -883.6    -883.6      0:07.2
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 884m.
#   https://opentopomap.org/#marker=15/51.883946/-3.4365
# You are 19m from the nearest named hill top, "Pen y Fan",
#   ranked the 826th heighest in GB.
#   http://hillsummits.org.uk/htm_summit/2226.htm
# Number of function evaluations: 489200.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400     -656.9872 -656.9872   0:00.0
# 1     800     -656.9872 -631.9152   0:00.0
# 2     1200    -742.0325 -742.0325   0:00.1
# 3     1600    -742.0325 -599.0885   0:00.1
# 20    8400    -1300.681 -1300.681   0:00.7
# 40    16400   -1308.926 -1308.896   0:01.4
# 60    24400   -1309.1   -1309.1     0:02.1
# 80    32400   -1309.1   -1309.1     0:02.8
# 100   40400   -1309.1   -1309.1     0:03.5
# 120   48400   -1309.1   -1309.1     0:04.1
# 140   56400   -1309.1   -1309.1     0:04.5
# 149   59600   -1309.1   -1309.1     0:04.7
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 1309m.
#   https://opentopomap.org/#marker=15/57.070204/-3.669488
# You are 31m from the nearest named hill top, "Ben Macdui",
#   ranked the 2d heighest in GB.
#   http://hillsummits.org.uk/htm_summit/518.htm
# Number of function evaluations: 548800.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400     -601.1342 -601.1342   0:00.0
# 1     800     -601.1342 -490.5791   0:00.0
# 2     1200    -625.8589 -625.8589   0:00.1
# 3     1600    -736.2528 -736.2528   0:00.1
# 20    8400    -1224.135 -1128.565   0:00.8
# 40    16400   -1307.747 -1305.487   0:01.4
# 60    24400   -1309.1   -1309.1     0:02.1
# 80    32400   -1309.1   -1309.1     0:02.8
# 100   40400   -1309.1   -1309.1     0:03.4
# 120   48400   -1309.1   -1309.1     0:04.0
# 140   56400   -1309.1   -1309.1     0:04.4
# 152   60800   -1309.1   -1309.1     0:04.7
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 1309m.
#   https://opentopomap.org/#marker=15/57.070204/-3.669488
# You are 31m from the nearest named hill top, "Ben Macdui",
#   ranked the 2d heighest in GB.
#   http://hillsummits.org.uk/htm_summit/518.htm
# Number of function evaluations: 609600.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400     -789.1811 -789.1811   0:00.0
# 1     800     -888.847  -888.847    0:00.0
# 2     1200    -888.847  -754.2339   0:00.1
# 3     1600    -888.847  -831.9721   0:00.1
# 20    8400    -1027.758 -985.1219   0:00.7
# 40    16400   -1306.392 -1306.392   0:01.4
# 60    24400   -1309.058 -1308.48    0:02.1
# 80    32400   -1309.1   -1309.1     0:02.8
# 100   40400   -1309.1   -1309.1     0:03.5
# 120   48400   -1309.1   -1309.1     0:04.2
# 140   56400   -1309.1   -1309.1     0:04.8
# 160   64400   -1309.1   -1309.1     0:05.2
# 171   68400   -1309.1   -1309.1     0:05.4
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 1309m.
#   https://opentopomap.org/#marker=15/57.070204/-3.669488
# You are 31m from the nearest named hill top, "Ben Macdui",
#   ranked the 2d heighest in GB.
#   http://hillsummits.org.uk/htm_summit/518.htm
# Number of function evaluations: 678000.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400     -588.8259 -588.8259   0:00.0
# 1     800     -740.5832 -740.5832   0:00.0
# 2     1200    -903.6685 -903.6685   0:00.1
# 3     1600    -903.6685 -795.2621   0:00.1
# 20    8400    -957.3491 -925.6549   0:00.9
# 40    16400   -1188.423 -952.5826   0:01.7
# 60    24400   -1188.423 -1141.577   0:02.4
# 80    32400   -1188.423 -1146.697   0:03.3
# 100   40400   -1188.423 -1146.7     0:04.0
# 120   48400   -1188.423 -1146.7     0:04.9
# 140   56400   -1188.423 -1146.7     0:05.7
# 160   64400   -1188.423 -1146.7     0:06.3
# 179   71600   -1188.423 -1146.7     0:06.9
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 1147m.
#   https://opentopomap.org/#marker=15/56.813544/-4.464956
# You are 31m from the nearest named hill top, "Ben Alder",
#   ranked the 43d heighest in GB.
#   http://hillsummits.org.uk/htm_summit/345.htm
# Number of function evaluations: 749600.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400     -628.5458 -628.5458   0:00.0
# 1     800     -787.4493 -787.4493   0:00.1
# 2     1200    -787.4493 -625.283    0:00.1
# 3     1600    -787.4493 -768.6209   0:00.1
# 20    8400    -1288.754 -1249.491   0:00.7
# 40    16400   -1309.093 -1309.049   0:01.5
# 60    24400   -1309.1   -1309.1     0:02.2
# 80    32400   -1309.1   -1309.1     0:02.9
# 100   40400   -1309.1   -1309.1     0:03.6
# 120   48400   -1309.1   -1309.1     0:04.1
# 140   56400   -1309.1   -1309.1     0:04.6
# 144   57600   -1309.1   -1309.1     0:04.6
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 1309m.
#   https://opentopomap.org/#marker=15/57.070204/-3.669488
# You are 31m from the nearest named hill top, "Ben Macdui",
#   ranked the 2d heighest in GB.
#   http://hillsummits.org.uk/htm_summit/518.htm
# Number of function evaluations: 807200.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400     -877.7419 -877.7419   0:00.0
# 1     800     -930.306  -930.306    0:00.1
# 2     1200    -930.306  -863.5258   0:00.1
# 3     1600    -930.306  -781.5495   0:00.1
# 20    8400    -1307.116 -1299.878   0:00.9
# 40    16400   -1309.099 -1309.099   0:01.6
# 60    24400   -1309.1   -1309.1     0:02.4
# 80    32400   -1309.1   -1309.1     0:03.1
# 100   40400   -1309.1   -1309.1     0:03.7
# 120   48400   -1309.1   -1309.1     0:04.2
# 136   54400   -1309.1   -1309.1     0:04.6
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 1309m.
#   https://opentopomap.org/#marker=15/57.070204/-3.669488
# You are 31m from the nearest named hill top, "Ben Macdui",
#   ranked the 2d heighest in GB.
#   http://hillsummits.org.uk/htm_summit/518.htm
# Number of function evaluations: 861600.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400     -852.1817 -852.1817   0:00.0
# 1     800     -852.1817 -804.6981   0:00.0
# 2     1200    -869.5937 -869.5937   0:00.1
# 3     1600    -869.5937 -828.3632   0:00.1
# 20    8400    -1263.344 -1248.741   0:00.8
# 40    16400   -1308.751 -1307.719   0:01.4
# 60    24400   -1309.1   -1309.1     0:02.1
# 80    32400   -1309.1   -1309.1     0:02.8
# 100   40400   -1309.1   -1309.1     0:03.6
# 120   48400   -1309.1   -1309.1     0:04.3
# 140   56400   -1309.1   -1309.1     0:04.8
# 154   61600   -1309.1   -1309.1     0:05.1
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 1309m.
#   https://opentopomap.org/#marker=15/57.070204/-3.669488
# You are 31m from the nearest named hill top, "Ben Macdui",
#   ranked the 2d heighest in GB.
#   http://hillsummits.org.uk/htm_summit/518.htm
# Number of function evaluations: 923200.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400     -518.0484 -518.0484   0:00.0
# 1     800     -949.6037 -949.6037   0:00.0
# 2     1200    -1057.264 -1057.264   0:00.1
# 3     1600    -1057.264 -711.322    0:00.1
# 20    8400    -1258.751 -934.1732   0:00.9
# 40    16400   -1258.751 -1218.278   0:01.8
# 60    24400   -1308.408 -1308.408   0:02.7
# 80    32400   -1309.1   -1309.1     0:03.4
# 100   40400   -1309.1   -1309.1     0:04.2
# 120   48400   -1309.1   -1309.1     0:05.0
# 140   56400   -1309.1   -1309.1     0:05.6
# 160   64400   -1309.1   -1309.1     0:06.2
# 172   68800   -1309.1   -1309.1     0:06.4
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 1309m.
#   https://opentopomap.org/#marker=15/57.070204/-3.669488
# You are 31m from the nearest named hill top, "Ben Macdui",
#   ranked the 2d heighest in GB.
#   http://hillsummits.org.uk/htm_summit/518.htm
# Number of function evaluations: 992000.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400     -788.199  -788.199    0:00.0
# 1     800     -788.199  -769.2836   0:00.0
# 2     1200    -1097.522 -1097.522   0:00.1
# 3     1600    -1097.522 -641.897    0:00.1
# 20    8400    -1235.465 -1057.926   0:00.9
# 40    16400   -1308.031 -1308.031   0:01.6
# 60    24400   -1309.088 -1309.088   0:02.3
# 80    32400   -1309.1   -1309.1     0:03.1
# 100   40400   -1309.1   -1309.1     0:03.9
# 120   48400   -1309.1   -1309.1     0:04.6
# 140   56400   -1309.1   -1309.1     0:05.0
# 160   64400   -1309.1   -1309.1     0:05.5
# 163   65200   -1309.1   -1309.1     0:05.6
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 1309m.
#   https://opentopomap.org/#marker=15/57.070204/-3.669488
# You are 31m from the nearest named hill top, "Ben Macdui",
#   ranked the 2d heighest in GB.
#   http://hillsummits.org.uk/htm_summit/518.htm
# Number of function evaluations: 1057200.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400     -580.2462 -580.2462   0:00.0
# 1     800     -1054.576 -1054.576   0:00.0
# 2     1200    -1054.576 -667.0361   0:00.1
# 3     1600    -1054.576 -735.8732   0:00.1
# 20    8400    -1240.104 -1111.375   0:00.8
# 40    16400   -1308.235 -1307.529   0:01.6
# 60    24400   -1309.1   -1309.1     0:02.3
# 80    32400   -1309.1   -1309.1     0:03.1
# 100   40400   -1309.1   -1309.1     0:03.8
# 120   48400   -1309.1   -1309.1     0:04.3
# 140   56400   -1309.1   -1309.1     0:04.8
# 150   60000   -1309.1   -1309.1     0:05.0
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 1309m.
#   https://opentopomap.org/#marker=15/57.070204/-3.669488
# You are 31m from the nearest named hill top, "Ben Macdui",
#   ranked the 2d heighest in GB.
#   http://hillsummits.org.uk/htm_summit/518.htm
# Number of function evaluations: 1117200.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400     -891.2207 -891.2207   0:00.0
# 1     800     -891.2207 -749.8942   0:00.0
# 2     1200    -1015.871 -1015.871   0:00.1
# 3     1600    -1015.871 -891.4344   0:00.1
# 20    8400    -1298.927 -1284.028   0:00.8
# 40    16400   -1309.09  -1309.072   0:01.5
# 60    24400   -1309.1   -1309.1     0:02.2
# 80    32400   -1309.1   -1309.1     0:02.9
# 100   40400   -1309.1   -1309.1     0:03.6
# 120   48400   -1309.1   -1309.1     0:04.1
# 140   56400   -1309.1   -1309.1     0:04.5
# 143   57200   -1309.1   -1309.1     0:04.6
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 1309m.
#   https://opentopomap.org/#marker=15/57.070204/-3.669488
# You are 31m from the nearest named hill top, "Ben Macdui",
#   ranked the 2d heighest in GB.
#   http://hillsummits.org.uk/htm_summit/518.htm
# Number of function evaluations: 1174400.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400     -848.661  -848.661    0:00.0
# 1     800     -848.661  -741.322    0:00.1
# 2     1200    -848.661  -781.2201   0:00.1
# 3     1600    -873.1924 -873.1924   0:00.1
# 20    8400    -1100.794 -1100.794   0:00.8
# 40    16400   -1301.718 -1275.683   0:01.5
# 60    24400   -1308.921 -1308.921   0:02.3
# 80    32400   -1309.1   -1309.1     0:03.0
# 100   40400   -1309.1   -1309.1     0:03.7
# 120   48400   -1309.1   -1309.1     0:04.5
# 140   56400   -1309.1   -1309.1     0:05.0
# 160   64400   -1309.1   -1309.1     0:05.5
# 173   69200   -1309.1   -1309.1     0:05.7
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 1309m.
#   https://opentopomap.org/#marker=15/57.070204/-3.669488
# You are 31m from the nearest named hill top, "Ben Macdui",
#   ranked the 2d heighest in GB.
#   http://hillsummits.org.uk/htm_summit/518.htm
# Number of function evaluations: 1243600.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400     -594.2075 -594.2075   0:00.0
# 1     800     -610.3744 -610.3744   0:00.0
# 2     1200    -798.6598 -798.6598   0:00.1
# 3     1600    -822.7769 -822.7769   0:00.1
# 20    8400    -1160.53  -929.439    0:00.8
# 40    16400   -1160.53  -826.9878   0:01.6
# 60    24400   -1160.53  -931.9405   0:02.3
# 80    32400   -1160.53  -941.9935   0:03.1
# 100   40400   -1160.53  -942        0:03.8
# 120   48400   -1160.53  -942        0:04.5
# 140   56400   -1160.53  -942        0:05.0
# 160   64400   -1160.53  -942        0:05.6
# 180   72400   -1160.53  -942        0:06.1
# 181   72400   -1160.53  -942        0:06.1
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 942m.
#   https://opentopomap.org/#marker=15/57.099128/-4.260156
# You are 14m from the nearest named hill top, "Carn Ban",
#   ranked the 509th heighest in GB.
#   http://hillsummits.org.uk/htm_summit/622.htm
# Number of function evaluations: 1316000.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400     -266.7536 -266.7536   0:00.0
# 1     800     -536.6021 -536.6021   0:00.0
# 2     1200    -554.8726 -554.8726   0:00.1
# 3     1600    -554.8726 -539.2208   0:00.1
# 20    8400    -848.369  -680.6009   0:00.8
# 40    16400   -848.369  -746.8696   0:01.6
# 60    24400   -848.369  -748.7952   0:02.3
# 80    32400   -848.369  -748.8      0:02.9
# 100   40400   -848.369  -748.8      0:03.7
# 120   48400   -848.369  -748.8      0:04.5
# 140   56400   -848.369  -748.8      0:04.9
# 160   64400   -848.369  -748.8      0:05.4
# 162   64800   -848.369  -748.8      0:05.4
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 749m.
#   https://opentopomap.org/#marker=15/52.467698/-3.782989
# You are 83m from the nearest named hill top, "Pumlumon Fawr",
#   ranked the 1842d heighest in GB.
#   http://hillsummits.org.uk/htm_summit/2161.htm
# Number of function evaluations: 1380800.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400     -888.7604 -888.7604   0:00.0
# 1     800     -888.7604 -537.1179   0:00.0
# 2     1200    -888.7604 -822.0982   0:00.1
# 3     1600    -888.7604 -859.6491   0:00.1
# 20    8400    -1252.827 -1252.827   0:00.8
# 40    16400   -1309.089 -1309.087   0:01.5
# 60    24400   -1309.1   -1309.1     0:02.2
# 80    32400   -1309.1   -1309.1     0:02.9
# 100   40400   -1309.1   -1309.1     0:03.6
# 120   48400   -1309.1   -1309.1     0:04.2
# 140   56400   -1309.1   -1309.1     0:04.6
# 146   58400   -1309.1   -1309.1     0:04.7
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 1309m.
#   https://opentopomap.org/#marker=15/57.070204/-3.669488
# You are 31m from the nearest named hill top, "Ben Macdui",
#   ranked the 2d heighest in GB.
#   http://hillsummits.org.uk/htm_summit/518.htm
# Number of function evaluations: 1439200.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400     -800.2541 -800.2541   0:00.0
# 1     800     -889.7512 -889.7512   0:00.1
# 2     1200    -889.7512 -800.2524   0:00.1
# 3     1600    -1070.377 -1070.377   0:00.1
# 20    8400    -1122.806 -1040.414   0:00.8
# 40    16400   -1303.155 -1302.629   0:01.5
# 60    24400   -1309.097 -1309.097   0:02.2
# 80    32400   -1309.1   -1309.1     0:02.9
# 100   40400   -1309.1   -1309.1     0:03.7
# 120   48400   -1309.1   -1309.1     0:04.4
# 140   56400   -1309.1   -1309.1     0:05.0
# 157   62800   -1309.1   -1309.1     0:05.4
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 1309m.
#   https://opentopomap.org/#marker=15/57.070204/-3.669488
# You are 31m from the nearest named hill top, "Ben Macdui",
#   ranked the 2d heighest in GB.
#   http://hillsummits.org.uk/htm_summit/518.htm
# Number of function evaluations: 1502000.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400     -583.2001 -583.2001   0:00.0
# 1     800     -583.2001 -504.6955   0:00.0
# 2     1200    -655.5451 -655.5451   0:00.1
# 3     1600    -861.976  -861.976    0:00.1
# 20    8400    -1275.254 -1152.381   0:00.8
# 40    16400   -1308.964 -1308.852   0:01.6
# 60    24400   -1309.1   -1309.1     0:02.3
# 80    32400   -1309.1   -1309.1     0:03.1
# 100   40400   -1309.1   -1309.1     0:04.0
# 120   48400   -1309.1   -1309.1     0:04.6
# 140   56400   -1309.1   -1309.1     0:05.1
# 151   60400   -1309.1   -1309.1     0:05.3
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 1309m.
#   https://opentopomap.org/#marker=15/57.070204/-3.669488
# You are 31m from the nearest named hill top, "Ben Macdui",
#   ranked the 2d heighest in GB.
#   http://hillsummits.org.uk/htm_summit/518.htm
# Number of function evaluations: 1562400.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400     -818.9716 -818.9716   0:00.0
# 1     800     -871.6474 -871.6474   0:00.0
# 2     1200    -916.6862 -916.6862   0:00.1
# 3     1600    -916.6862 -877.8071   0:00.1
# 20    8400    -1306.543 -1292.267   0:00.8
# 40    16400   -1309.086 -1309.086   0:01.7
# 60    24400   -1309.1   -1309.1     0:02.4
# 80    32400   -1309.1   -1309.1     0:03.1
# 100   40400   -1309.1   -1309.1     0:03.8
# 120   48400   -1309.1   -1309.1     0:04.3
# 140   56400   -1309.1   -1309.1     0:04.7
# 145   58000   -1309.1   -1309.1     0:04.8
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 1309m.
#   https://opentopomap.org/#marker=15/57.070204/-3.669488
# You are 31m from the nearest named hill top, "Ben Macdui",
#   ranked the 2d heighest in GB.
#   http://hillsummits.org.uk/htm_summit/518.htm
# Number of function evaluations: 1620400.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400     -913.5501 -913.5501   0:00.0
# 1     800     -913.5501 -830.473    0:00.0
# 2     1200    -913.5501 -667.0011   0:00.1
# 3     1600    -913.5501 -911.4785   0:00.1
# 20    8400    -1221.736 -1210.716   0:00.9
# 40    16400   -1309.003 -1309.003   0:01.7
# 60    24400   -1309.1   -1309.1     0:02.5
# 80    32400   -1309.1   -1309.1     0:03.3
# 100   40400   -1309.1   -1309.1     0:04.0
# 120   48400   -1309.1   -1309.1     0:04.5
# 140   56400   -1309.1   -1309.1     0:05.0
# 150   60000   -1309.1   -1309.1     0:05.2
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 1309m.
#   https://opentopomap.org/#marker=15/57.070204/-3.669488
# You are 31m from the nearest named hill top, "Ben Macdui",
#   ranked the 2d heighest in GB.
#   http://hillsummits.org.uk/htm_summit/518.htm
# Number of function evaluations: 1680400.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400     -918.3448 -918.3448   0:00.0
# 1     800     -918.3448 -767.4129   0:00.0
# 2     1200    -918.3448 -687.8958   0:00.1
# 3     1600    -918.3448 -774.5883   0:00.1
# 20    8400    -1162.593 -1162.593   0:00.8
# 40    16400   -1224.043 -982.9709   0:01.5
# 60    24400   -1304.917 -1293.204   0:02.3
# 80    32400   -1309.099 -1309.098   0:03.1
# 100   40400   -1309.1   -1309.1     0:03.9
# 120   48400   -1309.1   -1309.1     0:04.7
# 140   56400   -1309.1   -1309.1     0:05.5
# 160   64400   -1309.1   -1309.1     0:06.1
# 178   71200   -1309.1   -1309.1     0:06.5
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 1309m.
#   https://opentopomap.org/#marker=15/57.070204/-3.669488
# You are 31m from the nearest named hill top, "Ben Macdui",
#   ranked the 2d heighest in GB.
#   http://hillsummits.org.uk/htm_summit/518.htm
# Number of function evaluations: 1751600.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400     -675.3562 -675.3562   0:00.0
# 1     800     -989.6785 -989.6785   0:00.0
# 2     1200    -999.1545 -999.1545   0:00.1
# 3     1600    -999.1545 -915.0536   0:00.1
# 20    8400    -1306.639 -1306.639   0:00.8
# 40    16400   -1309.084 -1309.084   0:01.6
# 60    24400   -1309.1   -1309.1     0:02.4
# 80    32400   -1309.1   -1309.1     0:03.3
# 100   40400   -1309.1   -1309.1     0:04.1
# 120   48400   -1309.1   -1309.1     0:04.6
# 140   56400   -1309.1   -1309.1     0:05.1
# 142   56800   -1309.1   -1309.1     0:05.1
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 1309m.
#   https://opentopomap.org/#marker=15/57.070204/-3.669488
# You are 31m from the nearest named hill top, "Ben Macdui",
#   ranked the 2d heighest in GB.
#   http://hillsummits.org.uk/htm_summit/518.htm
# Number of function evaluations: 1808400.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400     -490.4726 -490.4726   0:00.0
# 1     800     -570.4119 -570.4119   0:00.0
# 2     1200    -576.2713 -576.2713   0:00.1
# 3     1600    -895.2943 -895.2943   0:00.1
# 20    8400    -1228.611 -1228.159   0:00.8
# 40    16400   -1308.549 -1308.549   0:01.5
# 60    24400   -1309.1   -1309.1     0:02.4
# 80    32400   -1309.1   -1309.1     0:03.0
# 100   40400   -1309.1   -1309.1     0:03.7
# 120   48400   -1309.1   -1309.1     0:04.3
# 140   56400   -1309.1   -1309.1     0:04.7
# 149   59600   -1309.1   -1309.1     0:04.9
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 1309m.
#   https://opentopomap.org/#marker=15/57.070204/-3.669488
# You are 31m from the nearest named hill top, "Ben Macdui",
#   ranked the 2d heighest in GB.
#   http://hillsummits.org.uk/htm_summit/518.htm
# Number of function evaluations: 1868000.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400     -896.6541 -896.6541   0:00.0
# 1     800     -1022.886 -1022.886   0:00.0
# 2     1200    -1119.527 -1119.527   0:00.1
# 3     1600    -1119.527 -993.6178   0:00.1
# 20    8400    -1303.397 -1286.227   0:00.7
# 40    16400   -1303.397 -1293.862   0:01.4
# 60    24400   -1303.397 -1293.9     0:02.1
# 80    32400   -1303.397 -1293.9     0:02.8
# 100   40400   -1303.397 -1293.9     0:03.4
# 120   48400   -1303.397 -1293.9     0:03.8
# 140   56400   -1303.397 -1293.9     0:04.4
# 144   57600   -1303.397 -1293.9     0:04.5
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 1294m.
#   https://opentopomap.org/#marker=15/57.078398/-3.728443
# You are 10m from the nearest named hill top, "Braeriach",
#   ranked the 3d heighest in GB.
# Number of function evaluations: 1925600.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400     -392.3875 -392.3875   0:00.0
# 1     800     -519.5293 -519.5293   0:00.1
# 2     1200    -997.7124 -997.7124   0:00.1
# 3     1600    -1148.242 -1148.242   0:00.1
# 20    8400    -1305.236 -1305.236   0:01.0
# 40    16400   -1308.408 -1308.408   0:02.0
# 60    24400   -1309.1   -1309.1     0:02.9
# 80    32400   -1309.1   -1309.1     0:03.7
# 100   40400   -1309.1   -1309.1     0:04.6
# 120   48400   -1309.1   -1309.1     0:05.4
# 140   56400   -1309.1   -1309.1     0:06.0
# 152   60800   -1309.1   -1309.1     0:06.3
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 1309m.
#   https://opentopomap.org/#marker=15/57.070204/-3.669488
# You are 31m from the nearest named hill top, "Ben Macdui",
#   ranked the 2d heighest in GB.
#   http://hillsummits.org.uk/htm_summit/518.htm
# Number of function evaluations: 1986400.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400     -771.3413 -771.3413   0:00.0
# 1     800     -861.9283 -861.9283   0:00.1
# 2     1200    -944.8028 -944.8028   0:00.1
# 3     1600    -944.8028 -785.6957   0:00.1
# 20    8400    -1278.83  -1220.796   0:00.9
# 40    16400   -1308.748 -1304.8     0:01.7
# 60    24400   -1309.1   -1309.1     0:02.6
# 80    32400   -1309.1   -1309.1     0:03.4
# 100   40400   -1309.1   -1309.1     0:04.2
# 120   48400   -1309.1   -1309.1     0:04.9
# 140   56400   -1309.1   -1309.1     0:05.5
# 156   62400   -1309.1   -1309.1     0:05.8
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 1309m.
#   https://opentopomap.org/#marker=15/57.070204/-3.669488
# You are 31m from the nearest named hill top, "Ben Macdui",
#   ranked the 2d heighest in GB.
#   http://hillsummits.org.uk/htm_summit/518.htm
# Number of function evaluations: 2048800.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400     -507.6953 -507.6953   0:00.0
# 1     800     -693.9356 -693.9356   0:00.1
# 2     1200    -1064.396 -1064.396   0:00.1
# 3     1600    -1064.396 -911.741    0:00.1
# 20    8400    -1297.304 -1242.207   0:00.8
# 40    16400   -1308.888 -1308.772   0:01.6
# 60    24400   -1309.1   -1309.1     0:02.5
# 80    32400   -1309.1   -1309.1     0:03.2
# 100   40400   -1309.1   -1309.1     0:04.0
# 120   48400   -1309.1   -1309.1     0:04.6
# 140   56400   -1309.1   -1309.1     0:05.1
# 149   59600   -1309.1   -1309.1     0:05.3
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 1309m.
#   https://opentopomap.org/#marker=15/57.070204/-3.669488
# You are 31m from the nearest named hill top, "Ben Macdui",
#   ranked the 2d heighest in GB.
#   http://hillsummits.org.uk/htm_summit/518.htm
# Number of function evaluations: 2108400.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400     -577.2642 -577.2642   0:00.0
# 1     800     -577.2642 -520.1677   0:00.0
# 2     1200    -577.2642 -473.6649   0:00.1
# 3     1600    -712.6272 -712.6272   0:00.1
# 20    8400    -826.1515 -703.0241   0:00.8
# 40    16400   -826.1515 -748.6292   0:01.7
# 60    24400   -826.1515 -748.7999   0:02.8
# 80    32400   -826.1515 -748.8      0:03.7
# 100   40400   -826.1515 -748.8      0:04.6
# 120   48400   -826.1515 -748.8      0:05.4
# 140   56400   -826.1515 -748.8      0:05.9
# 149   59600   -826.1515 -748.8      0:06.1
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 749m.
#   https://opentopomap.org/#marker=15/52.467698/-3.782989
# You are 83m from the nearest named hill top, "Pumlumon Fawr",
#   ranked the 1842d heighest in GB.
#   http://hillsummits.org.uk/htm_summit/2161.htm
# Number of function evaluations: 2168000.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400     -900.4222 -900.4222   0:00.0
# 1     800     -918.0096 -918.0096   0:00.1
# 2     1200    -947.1835 -947.1835   0:00.1
# 3     1600    -1089.112 -1089.112   0:00.1
# 20    8400    -1222.996 -1183.201   0:00.8
# 40    16400   -1307.294 -1298.583   0:02.0
# 60    24400   -1309.1   -1309.1     0:03.0
# 80    32400   -1309.1   -1309.1     0:03.9
# 100   40400   -1309.1   -1309.1     0:05.0
# 120   48400   -1309.1   -1309.1     0:05.9
# 140   56400   -1309.1   -1309.1     0:06.8
# 159   63600   -1309.1   -1309.1     0:07.3
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 1309m.
#   https://opentopomap.org/#marker=15/57.070204/-3.669488
# You are 31m from the nearest named hill top, "Ben Macdui",
#   ranked the 2d heighest in GB.
#   http://hillsummits.org.uk/htm_summit/518.htm
# Number of function evaluations: 2231600.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400     -454.4099 -454.4099   0:00.0
# 1     800     -685.5987 -685.5987   0:00.1
# 2     1200    -751.8068 -751.8068   0:00.1
# 3     1600    -751.8068 -670.7946   0:00.1
# 20    8400    -1053.703 -1034.343   0:00.9
# 40    16400   -1305.979 -1305.979   0:01.8
# 60    24400   -1309.08  -1309.057   0:02.7
# 80    32400   -1309.1   -1309.1     0:03.5
# 100   40400   -1309.1   -1309.1     0:04.6
# 120   48400   -1309.1   -1309.1     0:05.5
# 140   56400   -1309.1   -1309.1     0:06.1
# 160   64400   -1309.1   -1309.1     0:06.7
# 165   66000   -1309.1   -1309.1     0:06.8
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 1309m.
#   https://opentopomap.org/#marker=15/57.070204/-3.669488
# You are 31m from the nearest named hill top, "Ben Macdui",
#   ranked the 2d heighest in GB.
#   http://hillsummits.org.uk/htm_summit/518.htm
# Number of function evaluations: 2297600.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400     -422.2651 -422.2651   0:00.0
# 1     800     -530.9191 -530.9191   0:00.1
# 2     1200    -782.2376 -782.2376   0:00.1
# 3     1600    -782.2376 -690.002    0:00.1
# 20    8400    -1270.472 -1270.472   0:01.0
# 40    16400   -1308.974 -1308.974   0:01.9
# 60    24400   -1309.1   -1309.1     0:02.6
# 80    32400   -1309.1   -1309.1     0:03.5
# 100   40400   -1309.1   -1309.1     0:04.2
# 120   48400   -1309.1   -1309.1     0:04.8
# 140   56400   -1309.1   -1309.1     0:05.4
# 149   59600   -1309.1   -1309.1     0:05.6
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 1309m.
#   https://opentopomap.org/#marker=15/57.070204/-3.669488
# You are 31m from the nearest named hill top, "Ben Macdui",
#   ranked the 2d heighest in GB.
#   http://hillsummits.org.uk/htm_summit/518.htm
# Number of function evaluations: 2357200.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400     -935.3344 -935.3344   0:00.0
# 1     800     -935.3344 -830.9267   0:00.1
# 2     1200    -935.3344 -846.7953   0:00.1
# 3     1600    -935.3344 -827.7948   0:00.1
# 20    8400    -1306.897 -1300.064   0:00.9
# 40    16400   -1309.099 -1309.099   0:01.7
# 60    24400   -1309.1   -1309.1     0:02.6
# 80    32400   -1309.1   -1309.1     0:03.5
# 100   40400   -1309.1   -1309.1     0:04.1
# 120   48400   -1309.1   -1309.1     0:04.6
# 136   54400   -1309.1   -1309.1     0:05.0
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 1309m.
#   https://opentopomap.org/#marker=15/57.070204/-3.669488
# You are 31m from the nearest named hill top, "Ben Macdui",
#   ranked the 2d heighest in GB.
#   http://hillsummits.org.uk/htm_summit/518.htm
# Number of function evaluations: 2411600.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400     -224.6803 -224.6803   0:00.0
# 1     800     -714.8776 -714.8776   0:00.1
# 2     1200    -858.4392 -858.4392   0:00.1
# 3     1600    -858.4392 -567.2906   0:00.1
# 20    8400    -1157.843 -1044.216   0:00.9
# 40    16400   -1307.916 -1300.861   0:01.8
# 60    24400   -1309.1   -1309.1     0:02.6
# 80    32400   -1309.1   -1309.1     0:03.5
# 100   40400   -1309.1   -1309.1     0:04.2
# 120   48400   -1309.1   -1309.1     0:05.1
# 140   56400   -1309.1   -1309.1     0:05.6
# 156   62400   -1309.1   -1309.1     0:06.0
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 1309m.
#   https://opentopomap.org/#marker=15/57.070204/-3.669488
# You are 31m from the nearest named hill top, "Ben Macdui",
#   ranked the 2d heighest in GB.
#   http://hillsummits.org.uk/htm_summit/518.htm
# Number of function evaluations: 2474000.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400     -921.6487 -921.6487   0:00.0
# 1     800     -921.6487 -673.7606   0:00.1
# 2     1200    -921.6487 -802.0631   0:00.1
# 3     1600    -921.6487 -858.5805   0:00.1
# 20    8400    -1305.767 -1305.767   0:00.8
# 40    16400   -1309.097 -1309.097   0:01.6
# 60    24400   -1309.1   -1309.1     0:02.4
# 80    32400   -1309.1   -1309.1     0:03.3
# 100   40400   -1309.1   -1309.1     0:04.1
# 120   48400   -1309.1   -1309.1     0:04.7
# 140   56400   -1309.1   -1309.1     0:05.2
# 150   60000   -1309.1   -1309.1     0:05.5
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 1309m.
#   https://opentopomap.org/#marker=15/57.070204/-3.669488
# You are 31m from the nearest named hill top, "Ben Macdui",
#   ranked the 2d heighest in GB.
#   http://hillsummits.org.uk/htm_summit/518.htm
# Number of function evaluations: 2534000.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400     -756.9294 -756.9294   0:00.0
# 1     800     -839.4402 -839.4402   0:00.1
# 2     1200    -839.4402 -831.288    0:00.1
# 3     1600    -897.9774 -897.9774   0:00.1
# 20    8400    -1304.312 -1281.423   0:00.9
# 40    16400   -1309.002 -1309.002   0:01.8
# 60    24400   -1309.1   -1309.1     0:02.6
# 80    32400   -1309.1   -1309.1     0:03.5
# 100   40400   -1309.1   -1309.1     0:04.2
# 120   48400   -1309.1   -1309.1     0:04.9
# 140   56400   -1309.1   -1309.1     0:05.4
# 148   59200   -1309.1   -1309.1     0:05.6
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 1309m.
#   https://opentopomap.org/#marker=15/57.070204/-3.669488
# You are 31m from the nearest named hill top, "Ben Macdui",
#   ranked the 2d heighest in GB.
#   http://hillsummits.org.uk/htm_summit/518.htm
# Number of function evaluations: 2593200.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400     -349.883  -349.883    0:00.0
# 1     800     -566.9509 -566.9509   0:00.1
# 2     1200    -566.9509 -530.3448   0:00.1
# 3     1600    -585.6004 -585.6004   0:00.1
# 20    8400    -891.6867 -542.9195   0:00.9
# 40    16400   -891.6867 -736.7218   0:01.8
# 60    24400   -891.6867 -748.7895   0:02.7
# 80    32400   -891.6867 -748.8      0:03.7
# 100   40400   -891.6867 -748.8      0:04.6
# 120   48400   -891.6867 -748.8      0:05.5
# 140   56400   -891.6867 -748.8      0:06.2
# 160   64000   -891.6867 -748.8      0:06.7
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 749m.
#   https://opentopomap.org/#marker=15/52.467698/-3.782989
# You are 83m from the nearest named hill top, "Pumlumon Fawr",
#   ranked the 1842d heighest in GB.
#   http://hillsummits.org.uk/htm_summit/2161.htm
# Number of function evaluations: 2657200.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400     -757.5599 -757.5599   0:00.0
# 1     800     -983.4079 -983.4079   0:00.1
# 2     1200    -983.4079 -802.1362   0:00.1
# 3     1600    -983.4079 -971.5058   0:00.1
# 20    8400    -1305.657 -1265.459   0:00.9
# 40    16400   -1309.096 -1309.096   0:01.7
# 60    24400   -1309.1   -1309.1     0:02.6
# 80    32400   -1309.1   -1309.1     0:03.4
# 100   40400   -1309.1   -1309.1     0:04.2
# 120   48400   -1309.1   -1309.1     0:04.7
# 140   56400   -1309.1   -1309.1     0:05.2
# 143   57200   -1309.1   -1309.1     0:05.3
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 1309m.
#   https://opentopomap.org/#marker=15/57.070204/-3.669488
# You are 31m from the nearest named hill top, "Ben Macdui",
#   ranked the 2d heighest in GB.
#   http://hillsummits.org.uk/htm_summit/518.htm
# Number of function evaluations: 2714400.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400     -352.4047 -352.4047   0:00.0
# 1     800     -784.1411 -784.1411   0:00.1
# 2     1200    -784.1411 -735.6271   0:00.1
# 3     1600    -784.1411 -774.5946   0:00.1
# 20    8400    -1108.939 -792.1459   0:01.1
# 40    16400   -1296.677 -1291.275   0:02.2
# 60    24400   -1309.09  -1309.084   0:03.2
# 80    32400   -1309.1   -1309.1     0:04.3
# 100   40400   -1309.1   -1309.1     0:05.3
# 120   48400   -1309.1   -1309.1     0:06.3
# 140   56400   -1309.1   -1309.1     0:07.2
# 160   64000   -1309.1   -1309.1     0:07.9
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 1309m.
#   https://opentopomap.org/#marker=15/57.070204/-3.669488
# You are 31m from the nearest named hill top, "Ben Macdui",
#   ranked the 2d heighest in GB.
#   http://hillsummits.org.uk/htm_summit/518.htm
# Number of function evaluations: 2778400.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400     -463.7266 -463.7266   0:00.0
# 1     800     -546.5275 -546.5275   0:00.1
# 2     1200    -744.6424 -744.6424   0:00.1
# 3     1600    -744.6424 -564.3019   0:00.1
# 20    8400    -1221.139 -1092.112   0:01.0
# 40    16400   -1308.594 -1308.594   0:02.2
# 60    24400   -1308.594 -1293.884   0:03.1
# 80    32400   -1308.594 -1293.9     0:03.9
# 100   40400   -1308.594 -1293.9     0:04.8
# 120   48400   -1308.594 -1293.9     0:05.3
# 140   56400   -1308.594 -1293.9     0:05.8
# 160   64400   -1308.594 -1293.9     0:06.3
# 164   65600   -1308.594 -1293.9     0:06.4
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 1294m.
#   https://opentopomap.org/#marker=15/57.078398/-3.728443
# You are 10m from the nearest named hill top, "Braeriach",
#   ranked the 3d heighest in GB.
# Number of function evaluations: 2844000.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400     -789.8687 -789.8687   0:00.0
# 1     800     -789.8687 -638.6701   0:00.1
# 2     1200    -789.8687 -732.6309   0:00.1
# 3     1600    -789.8687 -733.454    0:00.1
# 20    8400    -1260.546 -1260.546   0:00.9
# 40    16400   -1309.012 -1309.012   0:01.8
# 60    24400   -1309.1   -1309.1     0:02.7
# 80    32400   -1309.1   -1309.1     0:03.4
# 100   40400   -1309.1   -1309.1     0:04.3
# 120   48400   -1309.1   -1309.1     0:04.9
# 140   56400   -1309.1   -1309.1     0:05.4
# 152   60800   -1309.1   -1309.1     0:05.7
# Halting: No significant change for 100 iterations.
# Congratulations!
# ...
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400     -124.8109 -124.8109   0:00.0
# 1     800     -983.4467 -983.4467   0:00.1
# 2     1200    -983.4467 -631.9369   0:00.1
# 3     1600    -983.4467 -731.0139   0:00.1
# 20    8400    -1120.068 -657.2432   0:00.9
# 40    16400   -1120.068 -599.0123   0:02.0
# 60    24400   -1120.068 -750.1808   0:03.0
# 80    32400   -1245.341 -600.4436   0:03.9
# 100   40400   -1245.341 -634.7845   0:04.9
# 120   48400   -1245.341 -547.8761   0:05.9
# 140   56400   -1245.341 -509.1756   0:06.9
# 160   64400   -1245.341 -614.6078   0:07.9
# 180   72400   -1245.341 -651.6332   0:08.9
# 200   80400   -1245.341 -703.8344   0:10.0
# 220   88400   -1245.341 -808.8091   0:11.2
# 240   96400   -1245.341 -810.2997   0:12.4
# 260   104400  -1245.341 -810.3      0:13.5
# 280   112400  -1245.341 -810.3      0:14.6
# 300   120400  -1245.341 -810.3      0:15.5
# 320   128400  -1245.341 -810.3      0:16.3
# 334   133600  -1245.341 -810.3      0:16.9
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 810m.
#   https://opentopomap.org/#marker=15/51.962701/-3.14284
# You are 25m from the nearest named hill top, "Waun Fach",
#   ranked the 1326th heighest in GB.
#   http://hillsummits.org.uk/htm_summit/2229.htm
# Number of function evaluations: 5647200.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400     -575.5676 -575.5676   0:00.0
# 1     800     -621.3079 -621.3079   0:00.1
# 2     1200    -847.1684 -847.1684   0:00.1
# 3     1600    -977.8242 -977.8242   0:00.1
# 20    8400    -1270.402 -1248.72    0:01.0
# 40    16400   -1308.88  -1308.877   0:01.9
# 60    24400   -1309.1   -1309.1     0:02.8
# 80    32400   -1309.1   -1309.1     0:03.7
# 100   40400   -1309.1   -1309.1     0:04.6
# 120   48400   -1309.1   -1309.1     0:05.3
# 140   56400   -1309.1   -1309.1     0:05.8
# 150   60000   -1309.1   -1309.1     0:06.0
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 1309m.
#   https://opentopomap.org/#marker=15/57.070204/-3.669488
# You are 31m from the nearest named hill top, "Ben Macdui",
#   ranked the 2d heighest in GB.
#   http://hillsummits.org.uk/htm_summit/518.htm
# Number of function evaluations: 5707200.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400     -919.0675 -919.0675   0:00.0
# 1     800     -919.0675 -894.0079   0:00.1
# 2     1200    -1187.238 -1187.238   0:00.1
# 3     1600    -1187.238 -859.4679   0:00.1
# 20    8400    -1305.857 -1298.913   0:00.8
# 40    16400   -1309.099 -1309.099   0:01.5
# 60    24400   -1309.1   -1309.1     0:02.3
# 80    32400   -1309.1   -1309.1     0:03.1
# 100   40400   -1309.1   -1309.1     0:03.8
# 120   48400   -1309.1   -1309.1     0:04.4
# 136   54400   -1309.1   -1309.1     0:04.8
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 1309m.
#   https://opentopomap.org/#marker=15/57.070204/-3.669488
# You are 31m from the nearest named hill top, "Ben Macdui",
#   ranked the 2d heighest in GB.
#   http://hillsummits.org.uk/htm_summit/518.htm
# Number of function evaluations: 5761600.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400     -539.0096 -539.0096   0:00.0
# 1     800     -546.0859 -546.0859   0:00.1
# 2     1200    -909.9331 -909.9331   0:00.1
# 3     1600    -909.9331 -533.955    0:00.1
# 20    8400    -1206.447 -1206.447   0:00.9
# 40    16400   -1307.876 -1303.222   0:01.6
# 60    24400   -1309.1   -1309.1     0:02.4
# 80    32400   -1309.1   -1309.1     0:03.1
# 100   40400   -1309.1   -1309.1     0:03.9
# 120   48400   -1309.1   -1309.1     0:04.4
# 140   56400   -1309.1   -1309.1     0:05.0
# 154   61600   -1309.1   -1309.1     0:05.3
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 1309m.
#   https://opentopomap.org/#marker=15/57.070204/-3.669488
# You are 31m from the nearest named hill top, "Ben Macdui",
#   ranked the 2d heighest in GB.
#   http://hillsummits.org.uk/htm_summit/518.htm
# Number of function evaluations: 5823200.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400     -612.9166 -612.9166   0:00.0
# 1     800     -612.9166 -596.1976   0:00.1
# 2     1200    -612.9166 -515.1522   0:00.1
# 3     1600    -612.9166 -569.0924   0:00.1
# 20    8400    -866.6594 -786.4636   0:00.8
# 40    16400   -866.6594 -681.7189   0:01.5
# 60    24400   -866.6594 -708.5715   0:02.3
# 80    32400   -866.6594 -708.6      0:03.2
# 100   40400   -866.6594 -708.6      0:04.0
# 120   48400   -866.6594 -708.6      0:04.8
# 140   56400   -866.6594 -708.6      0:05.3
# 160   64400   -866.6594 -708.6      0:05.8
# 170   68000   -866.6594 -708.6      0:06.0
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 709m.
#   https://opentopomap.org/#marker=15/54.406536/-2.306155
# You are 36m from the nearest named hill top, "High Seat",
#   ranked the 2329th heighest in GB.
#   http://hillsummits.org.uk/htm_summit/2719.htm
# Number of function evaluations: 5891200.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400     -631.978  -631.978    0:00.0
# 1     800     -668.0497 -668.0497   0:00.0
# 2     1200    -759.0463 -759.0463   0:00.1
# 3     1600    -759.0463 -685.587    0:00.1
# 20    8400    -842.2952 -712.2468   0:00.8
# 40    16400   -842.2952 -748.6484   0:01.7
# 60    24400   -842.2952 -748.7999   0:02.6
# 80    32400   -842.2952 -748.8      0:03.5
# 100   40400   -842.2952 -748.8      0:04.4
# 120   48400   -842.2952 -748.8      0:05.0
# 140   56400   -842.2952 -748.8      0:05.5
# 154   61600   -842.2952 -748.8      0:05.8
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 749m.
#   https://opentopomap.org/#marker=15/52.467698/-3.782989
# You are 83m from the nearest named hill top, "Pumlumon Fawr",
#   ranked the 1842d heighest in GB.
#   http://hillsummits.org.uk/htm_summit/2161.htm
# Number of function evaluations: 5952800.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400     -338.1383 -338.1383   0:00.0
# 1     800     -625.9463 -625.9463   0:00.1
# 2     1200    -625.9463 -518.5917   0:00.1
# 3     1600    -625.9463 -497.2549   0:00.1
# 20    8400    -975.347  -877.8335   0:00.8
# 40    16400   -975.347  -748.7322   0:01.5
# 60    24400   -975.347  -748.7997   0:02.3
# 80    32400   -975.347  -748.8      0:03.2
# 100   40400   -975.347  -748.8      0:04.0
# 120   48400   -975.347  -748.8      0:04.6
# 140   56400   -975.347  -748.8      0:05.1
# 153   61200   -975.347  -748.8      0:05.4
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 749m.
#   https://opentopomap.org/#marker=15/52.467698/-3.782989
# You are 83m from the nearest named hill top, "Pumlumon Fawr",
#   ranked the 1842d heighest in GB.
#   http://hillsummits.org.uk/htm_summit/2161.htm
# Number of function evaluations: 6014000.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400     -532.0456 -532.0456   0:00.0
# 1     800     -619.3711 -619.3711   0:00.0
# 2     1200    -877.6325 -877.6325   0:00.1
# 3     1600    -877.6325 -686.7485   0:00.1
# 20    8400    -1159.646 -1159.646   0:00.9
# 40    16400   -1306.14  -1302.589   0:01.7
# 60    24400   -1309.099 -1309.099   0:02.6
# 80    32400   -1309.1   -1309.1     0:03.4
# 100   40400   -1309.1   -1309.1     0:04.3
# 120   48400   -1309.1   -1309.1     0:05.1
# 140   56400   -1309.1   -1309.1     0:05.7
# 159   63600   -1309.1   -1309.1     0:06.3
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 1309m.
#   https://opentopomap.org/#marker=15/57.070204/-3.669488
# You are 31m from the nearest named hill top, "Ben Macdui",
#   ranked the 2d heighest in GB.
#   http://hillsummits.org.uk/htm_summit/518.htm
# Number of function evaluations: 6077600.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400     -517.2101 -517.2101   0:00.0
# 1     800     -676.8216 -676.8216   0:00.0
# 2     1200    -820.8894 -820.8894   0:00.1
# 3     1600    -820.8894 -580.852    0:00.1
# 20    8400    -1292.225 -1292.225   0:00.9
# 40    16400   -1308.748 -1308.748   0:01.8
# 60    24400   -1309.1   -1309.1     0:02.6
# 80    32400   -1309.1   -1309.1     0:03.6
# 100   40400   -1309.1   -1309.1     0:04.5
# 120   48400   -1309.1   -1309.1     0:05.2
# 140   56400   -1309.1   -1309.1     0:05.8
# 150   60000   -1309.1   -1309.1     0:06.0
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 1309m.
#   https://opentopomap.org/#marker=15/57.070204/-3.669488
# You are 31m from the nearest named hill top, "Ben Macdui",
#   ranked the 2d heighest in GB.
#   http://hillsummits.org.uk/htm_summit/518.htm
# Number of function evaluations: 6137600.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400     -186.0254 -186.0254   0:00.0
# 1     800     -674.8857 -674.8857   0:00.1
# 2     1200    -847.981  -847.981    0:00.1
# 3     1600    -919.4534 -919.4534   0:00.1
# 20    8400    -1131.709 -981.4976   0:00.9
# 40    16400   -1196.073 -745.4842   0:01.7
# 60    24400   -1261.923 -1231.796   0:02.5
# 80    32400   -1308.753 -1308.043   0:03.4
# 100   40400   -1309.1   -1309.1     0:04.4
# 120   48400   -1309.1   -1309.1     0:05.2
# 140   56400   -1309.1   -1309.1     0:06.0
# 160   64400   -1309.1   -1309.1     0:06.7
# 180   72400   -1309.1   -1309.1     0:07.2
# 197   78800   -1309.1   -1309.1     0:07.6
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 1309m.
#   https://opentopomap.org/#marker=15/57.070204/-3.669488
# You are 31m from the nearest named hill top, "Ben Macdui",
#   ranked the 2d heighest in GB.
#   http://hillsummits.org.uk/htm_summit/518.htm
# Number of function evaluations: 6216400.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400     -851.3159 -851.3159   0:00.0
# 1     800     -976.0024 -976.0024   0:00.0
# 2     1200    -1206.708 -1206.708   0:00.1
# 3     1600    -1206.708 -1051.226   0:00.1
# 20    8400    -1307.113 -1305.819   0:01.0
# 40    16400   -1309.098 -1309.098   0:01.9
# 60    24400   -1309.1   -1309.1     0:02.8
# 80    32400   -1309.1   -1309.1     0:03.6
# 100   40400   -1309.1   -1309.1     0:04.5
# 120   48400   -1309.1   -1309.1     0:05.0
# 137   54800   -1309.1   -1309.1     0:05.4
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 1309m.
#   https://opentopomap.org/#marker=15/57.070204/-3.669488
# You are 31m from the nearest named hill top, "Ben Macdui",
#   ranked the 2d heighest in GB.
#   http://hillsummits.org.uk/htm_summit/518.htm
# Number of function evaluations: 6271200.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400     -1085.703 -1085.703   0:00.0
# 1     800     -1085.703 -839.6489   0:00.0
# 2     1200    -1085.703 -1018.849   0:00.1
# 3     1600    -1085.703 -859.2711   0:00.1
# 20    8400    -1291.676 -1278.781   0:00.8
# 40    16400   -1309.092 -1309.086   0:01.6
# 60    24400   -1309.1   -1309.1     0:02.5
# 80    32400   -1309.1   -1309.1     0:03.3
# 100   40400   -1309.1   -1309.1     0:04.2
# 120   48400   -1309.1   -1309.1     0:04.8
# 140   56000   -1309.1   -1309.1     0:05.3
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 1309m.
#   https://opentopomap.org/#marker=15/57.070204/-3.669488
# You are 31m from the nearest named hill top, "Ben Macdui",
#   ranked the 2d heighest in GB.
#   http://hillsummits.org.uk/htm_summit/518.htm
# Number of function evaluations: 6327200.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400     -512.4871 -512.4871   0:00.0
# 1     800     -755.6876 -755.6876   0:00.1
# 2     1200    -755.6876 -643.8681   0:00.1
# 3     1600    -755.6876 -754.3879   0:00.1
# 20    8400    -1304.662 -1274.94    0:00.9
# 40    16400   -1309.066 -1309.066   0:01.8
# 60    24400   -1309.1   -1309.1     0:02.7
# 80    32400   -1309.1   -1309.1     0:03.6
# 100   40400   -1309.1   -1309.1     0:04.4
# 120   48400   -1309.1   -1309.1     0:05.0
# 140   56400   -1309.1   -1309.1     0:05.5
# 143   57200   -1309.1   -1309.1     0:05.6
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 1309m.
#   https://opentopomap.org/#marker=15/57.070204/-3.669488
# You are 31m from the nearest named hill top, "Ben Macdui",
#   ranked the 2d heighest in GB.
#   http://hillsummits.org.uk/htm_summit/518.htm
# Number of function evaluations: 6384400.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400     -754.7556 -754.7556   0:00.0
# 1     800     -878.9885 -878.9885   0:00.1
# 2     1200    -878.9885 -702.342    0:00.1
# 3     1600    -878.9885 -806.159    0:00.1
# 20    8400    -912.3022 -867.3162   0:01.1
# 40    16400   -1304.755 -1291.394   0:02.0
# 60    24400   -1308.222 -1308.222   0:03.0
# 80    32400   -1309.1   -1309.1     0:04.0
# 100   40400   -1309.1   -1309.1     0:04.9
# 120   48400   -1309.1   -1309.1     0:05.8
# 140   56400   -1309.1   -1309.1     0:06.5
# 160   64400   -1309.1   -1309.1     0:07.2
# 171   68400   -1309.1   -1309.1     0:07.5
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 1309m.
#   https://opentopomap.org/#marker=15/57.070204/-3.669488
# You are 31m from the nearest named hill top, "Ben Macdui",
#   ranked the 2d heighest in GB.
#   http://hillsummits.org.uk/htm_summit/518.htm
# Number of function evaluations: 6452800.
# Minimising error measure
# Using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 400
# Iter. Eval.   Best      Current   Time m:s
# 0     400     -507.5194 -507.5194   0:00.0
# 1     800     -610.8387 -610.8387   0:00.1
# 2     1200    -610.8387 -519.5116   0:00.1
# 3     1600    -693.9307 -693.9307   0:00.1
# 20    8400    -1194.3   -1047.653   0:01.0
# 40    16400   -1298.599 -1281.631   0:02.0
# 60    24400   -1309.097 -1309.097   0:03.0
# 80    32400   -1309.1   -1309.1     0:04.1
# 100   40400   -1309.1   -1309.1     0:05.2
# 120   48400   -1309.1   -1309.1     0:06.1
# 140   56400   -1309.1   -1309.1     0:06.9
# 160   64400   -1309.1   -1309.1     0:07.6
# 165   66000   -1309.1   -1309.1     0:07.7
# Halting: No significant change for 100 iterations.
# Congratulations!
# You landed at an altitude of 1309m.
#   https://opentopomap.org/#marker=15/57.070213/-3.669488
# You are 30m from the nearest named hill top, "Ben Macdui",
#   ranked the 2d heighest in GB.
#   http://hillsummits.org.uk/htm_summit/518.htm
# Number of function evaluations: 6518800.

# %%
len(fs), len([x for x in fs if x > 1309]),  len([x for x in fs if x > 1310])
# Out:
# (100, 82, 0)

# %%
print(x0)
# Out:
# [[374963.3595085  500251.90104036]]

# %%
import numpy as np
# Visited points
points = np.array(points)
trajectory = np.array(trajectory)
c = nevis.Coords(gridx=x, gridy=y)
h, d = nevis.Hill.nearest(c)



import matplotlib.pyplot as plt
labels = {
    'Ben Nevis': nevis.ben(),
    h.name: h.coords,
    'You': c,
    'Init': nevis.Coords(gridx=x0[0, 0], gridy=x0[0, 1]),
}
nevis.plot(
    labels=labels,
    trajectory=trajectory,
    points=points,
)
plt.show()

# %%
points
# Out:
# array([], dtype=float64)
