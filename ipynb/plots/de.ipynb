# %%
import sys
sys.path.insert(0, "../../src/")
from framework import *
from algorithms import differential_evolution

differential_evolution.load_best_instance('../../result/june.db')
save_handler = SaveHandlerJSON('../../result/june/')

ins = differential_evolution.best_instance
ins.trial.params

ins.load_results(save_handler=save_handler, partial=False)

# %%
import numpy as np
maxima_heights = np.load('../../basin-problem/res/maxima_heights.npy')
anim = ResultAnimation(ins.results[2], maxima_heights, mode='iterations')
anim.save('animation/DE-iterations.mp4')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 4
#       2 maxima_heights = np.load('../../basin-problem/res/maxima_heights.npy')
#       3 anim = ResultAnimation(ins.results[2], maxima_heights, mode='iterations')
# ----> 4 anim.save('animaition/DE-iterations.mp4')
#
# File ~/projects/BenNevisBenchmark/ipynb/plots/../../src/framework/animation.py:594, in ResultAnimation.save(self, file_name, writer, fps)
#     577 def save(self, file_name='animation.mp4', writer='ffmpeg', fps=1):
#     578     """
#     579     Saves the animation to a video file.
#     580
#    (...)
#     592     None
#     593     """
# --> 594     self.anim.save(file_name, writer=writer, fps=fps)
#
# File ~/projects/BenNevisBenchmark/venv/lib/python3.10/site-packages/matplotlib/animation.py:1069, in Animation.save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1065 savefig_kwargs['transparent'] = False   # just to be safe!
#    1066 # canvas._is_saving = True makes the draw_event animation-starting
#    1067 # callback a no-op; canvas.manager = None prevents resizing the GUI
#    1068 # widget (both are likewise done in savefig()).
# -> 1069 with writer.saving(self._fig, filename, dpi), \
#    1070      cbook._setattr_cm(self._fig.canvas, _is_saving=True, manager=None):
#    1071     for anim in all_anim:
#    1072         anim._init_draw()  # Clear the initial frame
#
# File /usr/lib/python3.10/contextlib.py:135, in _GeneratorContextManager.__enter__(self)
#     133 del self.args, self.kwds, self.func
#     134 try:
# --> 135     return next(self.gen)
#     136 except StopIteration:
#     137     raise RuntimeError("generator didn't yield") from None
#
# File ~/projects/BenNevisBenchmark/venv/lib/python3.10/site-packages/matplotlib/animation.py:220, in AbstractMovieWriter.saving(self, fig, outfile, dpi, *args, **kwargs)
#     215     _log.info("Disabling savefig.bbox = 'tight', as it may cause "
#     216               "frame size to vary, which is inappropriate for "
#     217               "animation.")
#     219 # This particular sequence is what contextlib.contextmanager wants
# --> 220 self.setup(fig, outfile, dpi, *args, **kwargs)
#     221 with mpl.rc_context({'savefig.bbox': None}):
#     222     try:
#
# File ~/projects/BenNevisBenchmark/venv/lib/python3.10/site-packages/matplotlib/animation.py:307, in MovieWriter.setup(self, fig, outfile, dpi)
#     305 def setup(self, fig, outfile, dpi=None):
#     306     # docstring inherited
# --> 307     super().setup(fig, outfile, dpi=dpi)
#     308     self._w, self._h = self._adjust_frame_size()
#     309     # Run here so that grab_frame() can write the data to a pipe. This
#     310     # eliminates the need for temp files.
#
# File ~/projects/BenNevisBenchmark/venv/lib/python3.10/site-packages/matplotlib/animation.py:175, in AbstractMovieWriter.setup(self, fig, outfile, dpi)
#     161 """
#     162 Setup for writing the movie file.
#     163
#    (...)
#     172     in pixels of the resulting movie file.
#     173 """
#     174 # Check that path is valid
# --> 175 Path(outfile).parent.resolve(strict=True)
#     176 self.outfile = outfile
#     177 self.fig = fig
#
# File /usr/lib/python3.10/pathlib.py:1077, in Path.resolve(self, strict)
#    1074         raise RuntimeError("Symlink loop from %r" % e.filename)
#    1076 try:
# -> 1077     s = self._accessor.realpath(self, strict=strict)
#    1078 except OSError as e:
#    1079     check_eloop(e)
#
# File /usr/lib/python3.10/posixpath.py:396, in realpath(filename, strict)
#     393     """Return the canonical path of the specified filename, eliminating any
#     394 symbolic links encountered in the path."""
#     395     filename = os.fspath(filename)
# --> 396     path, ok = _joinrealpath(filename[:0], filename, strict, {})
#     397     return abspath(path)
#
# File /usr/lib/python3.10/posixpath.py:431, in _joinrealpath(path, rest, strict, seen)
#     429 newpath = join(path, name)
#     430 try:
# --> 431     st = os.lstat(newpath)
#     432 except OSError:
#     433     if strict:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'animaition'

# %%
ins.performance_measures()
# Out:
# {'success_rate': 0.8666666666666667,
#  'failure_rate': 0.1333333333333333,
#  'success_cnt': 39,
#  'avg_success_eval': np.float64(18107.30769230769),
#  'hv': np.float64(27640.333333333336),
#  'par2': 29026.333333333332,
#  'par10': 82359.66666666667,
#  'avg_height': np.float64(1339.6677961722007),
#  'ert': np.float64(25799.615384615383),
#  'sp': np.float64(20893.047337278105),
#  'success_rate_upper': np.float64(0.9374293636565032),
#  'success_rate_lower': np.float64(0.7382241775870269),
#  'success_rate_length': np.float64(0.19920518606947626),
#  'gary_ert': np.float64(2466.139705882353)}

# %%
ins.results[7].plot_local()

# %%
ins.performance_to_latex()
# Out:
# 'Differential Evolution\t& 45\t& 87\\%\t& 1340\t& \\(2.58 \\times 10^{4}\\) \t& \\(2.47 \\times 10^{3}\\) \\\\'

# %%
ins.plot_convergence_graph()

# %%
ins.plot_stacked_graph()

# %%
ins.plot_stacked_graph(mode='terminate')
