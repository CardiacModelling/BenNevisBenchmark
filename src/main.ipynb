# %%
from framework import *
from algorithms import *

# %%
algorithm = dual_annealing

# %%
algorithm.tune_params()
# Out:
# Calculating instance 1 / 15
# Running instance 1663337103.2668514
# {'algorithm_name': 'Dual Annealing',
#  'algorithm_version': 1,
#  'initial_temp': 25545.545545545545,
#  'maxiter': 2000,
#  'restart_temp_ratio': 3.511191734215135e-05}
# 100%|██████████| 10/10 [00:07<00:00,  1.37it/s]
# ert = inf
#
# Calculating instance 2 / 15
# Running instance 1663337103.2670076
# {'algorithm_name': 'Dual Annealing',
#  'algorithm_version': 1,
#  'initial_temp': 35255.25525525525,
#  'maxiter': 2000,
#  'restart_temp_ratio': 0.00032745491628777317}
# 100%|██████████| 10/10 [00:06<00:00,  1.45it/s]
# ert = 113323.0
#
# Calculating instance 3 / 15
# Running instance 1663337103.2670548
# {'algorithm_name': 'Dual Annealing',
#  'algorithm_version': 1,
#  'initial_temp': 32192.192192192193,
#  'maxiter': 2000,
#  'restart_temp_ratio': 5.8570208180566735e-05}
# 100%|██████████| 10/10 [00:06<00:00,  1.53it/s]
# ert = 97124.0
#
# Calculating instance 4 / 15
# Running instance 1663337103.2670949
# ...

# %%
instance = algorithm.best_instance
instance.print()
# Out:
# 1663337103.2673593
# {'algorithm_name': 'Dual Annealing',
#  'algorithm_version': 1,
#  'initial_temp': 31251.25125125125,
#  'maxiter': 2000,
#  'restart_temp_ratio': 5.0941380148163855e-05}

# %%
instance.plot_convergence_graph()

# %%
instance.plot_stacked_graph()

# %%
instance.print_results()
# Out:
# {'avg_height': 1274.7690944513884,
#  'avg_success_eval': 8015.5,
#  'ert': 49036.5,
#  'failure_rate': 0.8,
#  'hv': 8396.9,
#  'par10': 401603.1,
#  'par2': 81603.1,
#  'sp': 40077.5,
#  'success_cnt': 2,
#  'success_rate': 0.2}
# === Result #0 ===
# 10769
# 1663337246.3254416
# Number of function evals: 10769
# Congratulations!
# You landed at an altitude of 1309m.
#   https://opentopomap.org/#marker=15/57.070213/-3.669488
# You are 30m from the nearest named hill top, "Ben Macdui",
#   ranked the 2d heighest in GB.
#   http://hillsummits.org.uk/htm_summit/518.htm
#
# === Result #1 ===
# 9092
# 1663337244.484103
# Number of function evals: 9092
# Congratulations!
# You landed at an altitude of 1128m.
#   https://opentopomap.org/#marker=15/56.951851/-4.602348
# You are 24m from the nearest named hill top, "Creag Meagaidh",
#   ranked the 56th heighest in GB.
#   http://hillsummits.org.uk/htm_summit/658.htm
#
# === Result #2 ===
# 9341
# 1663337241.4520118
# ...

# %%
instance.plot_histogram()

# %%
instance.plot_ret_points()

# %%
algorithm.plot_all_measures()

# %%
algorithm.plot_two_measures(
    x_measure='avg_success_eval',
    y_measure='failure_rate',
)

# %%
algorithm.plot_tuning(
    param_x='initial_temp',
    param_y='restart_temp_ratio',
    measure_area='success_rate',
    measure_color='ert',
    y_log=True,
)

# %%
result = list(instance.results)[0]

# %%
result.plot_global()

# %%
result.plot_partial()
