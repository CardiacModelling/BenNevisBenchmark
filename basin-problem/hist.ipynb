# %%
import nevis 

data = nevis.gb()

d = data.flatten()
d = d[d > 0]

import matplotlib.pyplot as plt 

plt.hist(d, log=True, bins=50)
plt.title('Histogram of the heights of all points excluding sea')
plt.show()

# %%
plt.hist(d, log=True, bins=50)
plt.title('Histogram of the heights of all points excluding sea')
plt.show()
