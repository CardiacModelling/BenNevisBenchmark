# %%
import basin
import numpy as np
import nevis
import random

data = nevis.gb()


def find_labels(h):
    maxima, sn = basin.find_maxima(h)
    label = basin.find_basins(h, sn, maxima)
    return label, maxima

label, maxima = find_labels(data)
# Out:
# ......................................................................
# ......................................................................
# ......................................................................
# ......................................................................
# ......................................................................
# ......................................................................
# ......................................................................
# ......................................................................
# ......................................................................
# ......................................................................
# ......................................................................
# ......................................................................
# ......................................................................
# ...

# %%
heights = []

for x, y in maxima:
    heights.append(data[x, y])

# %%
import matplotlib.pyplot as plt 

plt.hist(heights, log=True)
plt.title('Histogram of the heights of local maixma')
plt.show()

# %%
plt.hist(heights)
plt.title('Histogram of the heights of local maixma')
plt.show()

# %%
print(len(heights))
# Out:
# 2138823
